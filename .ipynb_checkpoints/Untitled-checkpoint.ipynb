# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
# !pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 1.9 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.6 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [regex]
#    ---------- ----------------------------- 1/4 [regex]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [nltk]
# ...

# %%
nltk.download(['punkt', 'punkt_tab', 'stopwords', 'wordnet'])
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Abinash
# [nltk_data]     Bista\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\Abinash
# [nltk_data]     Bista\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Abinash
# [nltk_data]     Bista\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\Abinash
# [nltk_data]     Bista\AppData\Roaming\nltk_data...
# True

# %%
text = "Now I am become death, destroyer of worlds"

# %%
text = text.lower()
print("Lowercased:", text)
# Out:
# Lowercased: now i am become death, destroyer of worlds

# %%
tokens = word_tokenize(text)
print("Tokenized:", tokens)
# Out:
# Tokenized: ['now', 'i', 'am', 'become', 'death', ',', 'destroyer', 'of', 'worlds']

# %%
 token = [t for t in tokens if t not in string.punctuation]
print("No punctuation:", tokens)
# Out:
#   Cell In[11], line 1
#     tokens = [t for t in tokens if t not in string.punctuation]
#     ^
# IndentationError: unexpected indent

# %%
# !pip install transformers torch
# Out:
# ERROR: Could not find a version that satisfies the requirement trasformers (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for trasformers

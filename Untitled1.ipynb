# %%
# !pip install transformers torch
# Out:
# ...
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.2 MB 973.5 kB/s eta 0:00:11
#    -- ------------------------------------- 0.8/11.2 MB 1.1 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/11.2 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.2 MB 1.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/11.2 MB 1.2 MB/s eta 0:00:09
#    ------- -------------------------------- 2.1/11.2 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.2 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/11.2 MB 1.4 MB/s eta 0:00:06
# ...
